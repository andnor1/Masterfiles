# %%
import galois
import itertools

# Define the finite field GF(4) using the irreducible polynomial x^2 + x + 1
GF4 = galois.GF(2**2, irreducible_poly="x^2 + x + 1", repr="poly")

# Define a helper function to convert GF(4) elements into symbolic form
def to_symbolic_string(value):
    """
    Converts a GF(4) element into its symbolic representation.
    """
    if value == GF4(0):
        return "0"
    elif value == GF4(1):
        return "1"
    elif value == GF4(2):
        return "x"
    elif value == GF4(3):
        return "x + 1"

# Define F_0(x1, x2) and F_1(y1, y2)
def F_0(x1, x2):
    """
    Computes F_0(x1, x2) for two elements in GF(4).
    Example polynomial:: F_0(x1, x2) = x1^2 + x2
    """
    x1, x2 = GF4(x1), GF4(x2)  # Ensure inputs are GF(4) elements
    return x1**2 + x2  # Example of a degree 2 polynomial

def F_1(y1, y2):
    """
    Computes F_1(y1, y2) for two elements in GF(4).
    Example polynomial:: F_1(y1, y2) = y1 + y2
    """
    y1, y2 = GF4(y1), GF4(y2)  # Ensure inputs are GF(4) elements
    return y1 + y2  # Example of a degree 2 polynomial

# Generate all 2x2 matrices over GF(4)
elements = GF4.elements  # GF(4) elements: [0, 1, x, x + 1]
all_matrices = list(itertools.product(elements, repeat=4))  # Generate all 2x2 matrices

# Filter for invertible matrices
invertible_matrices = []
for matrix in all_matrices:
    a, b, c, d = matrix
    det = a * d - b * c  # Compute determinant
    if det != GF4(0):  # Check if determinant is non-zero
        invertible_matrices.append([[a, b], [c, d]])

# Compute results for all invertible matrices and all (c0, c1) combinations
results = {}
for i, M in enumerate(invertible_matrices):
    a, b = M[0]  # First row of the matrix
    c, d = M[1]  # Second row of the matrix

    # Example computation: use matrix rows as inputs to F_0 and F_1
    F_xa = (GF4([a, b]), GF4([c, d]))  # Treat rows as inputs to F_0 and F_1
    F_x = (GF4(["x + 1", "x"]), GF4(["x", "1"]))  # Fixed inputs for F(x)

    for c0, c1 in itertools.product(range(2), repeat=2):  # Iterate over c0, c1 in {0, 1}
        c0 = GF4(c0)
        c1 = GF4(c1)

        # Compute derivatives
        D_c_F0 = F_0(F_xa[0][0], F_xa[0][1]) + c0 * F_0(F_x[0][0], F_x[0][1]) + c1 * F_1(F_x[1][0], F_x[1][1])
        D_c_F1 = F_1(F_xa[1][0], F_xa[1][1]) + c0 * F_1(F_x[1][0], F_x[1][1]) + c1 * F_0(F_x[0][0], F_x[0][1])

        # Store results with symbolic representation
        results[f"Matrix {i}, c = ({c0}, {c1})"] = (D_c_F0, D_c_F1)

# Display results with symbolic representation
print("\n## Final Results (symbolic):")
for key, (expr1, expr2) in results.items():
    # Convert each element in D_c_F0 and D_c_F1 to symbolic strings
    expr1_sym = to_symbolic_string(expr1)
    expr2_sym = to_symbolic_string(expr2)
    print(f"{key}: (D_c_F0 = {expr1_sym}, D_c_F1 = {expr2_sym})")
# Out:
# ## Final Results (symbolic):
# Matrix 0, c = (0, 0): (D_c_F0 = 1, D_c_F1 = 1)
# Matrix 0, c = (0, 1): (D_c_F0 = x, D_c_F1 = 1)
# Matrix 0, c = (1, 0): (D_c_F0 = 1, D_c_F1 = x)
# Matrix 0, c = (1, 1): (D_c_F0 = x, D_c_F1 = x)
# Matrix 1, c = (0, 0): (D_c_F0 = 1, D_c_F1 = 0)
# Matrix 1, c = (0, 1): (D_c_F0 = x, D_c_F1 = 0)
# Matrix 1, c = (1, 0): (D_c_F0 = 1, D_c_F1 = x + 1)
# Matrix 1, c = (1, 1): (D_c_F0 = x, D_c_F1 = x + 1)
# Matrix 2, c = (0, 0): (D_c_F0 = 1, D_c_F1 = x + 1)
# Matrix 2, c = (0, 1): (D_c_F0 = x, D_c_F1 = x + 1)
# Matrix 2, c = (1, 0): (D_c_F0 = 1, D_c_F1 = 0)
# Matrix 2, c = (1, 1): (D_c_F0 = x, D_c_F1 = 0)
# Matrix 3, c = (0, 0): (D_c_F0 = 1, D_c_F1 = x)
# Matrix 3, c = (0, 1): (D_c_F0 = x, D_c_F1 = x)
# Matrix 3, c = (1, 0): (D_c_F0 = 1, D_c_F1 = 1)
# Matrix 3, c = (1, 1): (D_c_F0 = x, D_c_F1 = 1)
# Matrix 4, c = (0, 0): (D_c_F0 = 1, D_c_F1 = x)
# Matrix 4, c = (0, 1): (D_c_F0 = x, D_c_F1 = x)
# Matrix 4, c = (1, 0): (D_c_F0 = 1, D_c_F1 = 1)
# Matrix 4, c = (1, 1): (D_c_F0 = x, D_c_F1 = 1)
# Matrix 5, c = (0, 0): (D_c_F0 = 1, D_c_F1 = x + 1)
# Matrix 5, c = (0, 1): (D_c_F0 = x, D_c_F1 = x + 1)
# Matrix 5, c = (1, 0): (D_c_F0 = 1, D_c_F1 = 0)
# Matrix 5, c = (1, 1): (D_c_F0 = x, D_c_F1 = 0)
# Matrix 6, c = (0, 0): (D_c_F0 = 1, D_c_F1 = 0)
# Matrix 6, c = (0, 1): (D_c_F0 = x, D_c_F1 = 0)
# Matrix 6, c = (1, 0): (D_c_F0 = 1, D_c_F1 = x + 1)
# Matrix 6, c = (1, 1): (D_c_F0 = x, D_c_F1 = x + 1)
# Matrix 7, c = (0, 0): (D_c_F0 = 1, D_c_F1 = 1)
# Matrix 7, c = (0, 1): (D_c_F0 = x, D_c_F1 = 1)
# Matrix 7, c = (1, 0): (D_c_F0 = 1, D_c_F1 = x)
# Matrix 7, c = (1, 1): (D_c_F0 = x, D_c_F1 = x)
# Matrix 8, c = (0, 0): (D_c_F0 = 1, D_c_F1 = x + 1)
# Matrix 8, c = (0, 1): (D_c_F0 = x, D_c_F1 = x + 1)
# Matrix 8, c = (1, 0): (D_c_F0 = 1, D_c_F1 = 0)
# Matrix 8, c = (1, 1): (D_c_F0 = x, D_c_F1 = 0)
# Matrix 9, c = (0, 0): (D_c_F0 = 1, D_c_F1 = x)
# Matrix 9, c = (0, 1): (D_c_F0 = x, D_c_F1 = x)
# Matrix 9, c = (1, 0): (D_c_F0 = 1, D_c_F1 = 1)
# Matrix 9, c = (1, 1): (D_c_F0 = x, D_c_F1 = 1)
# Matrix 10, c = (0, 0): (D_c_F0 = 1, D_c_F1 = 1)
# Matrix 10, c = (0, 1): (D_c_F0 = x, D_c_F1 = 1)
# Matrix 10, c = (1, 0): (D_c_F0 = 1, D_c_F1 = x)
# Matrix 10, c = (1, 1): (D_c_F0 = x, D_c_F1 = x)
# Matrix 11, c = (0, 0): (D_c_F0 = 1, D_c_F1 = 0)
# Matrix 11, c = (0, 1): (D_c_F0 = x, D_c_F1 = 0)
# Matrix 11, c = (1, 0): (D_c_F0 = 1, D_c_F1 = x + 1)
# Matrix 11, c = (1, 1): (D_c_F0 = x, D_c_F1 = x + 1)
# Matrix 12, c = (0, 0): (D_c_F0 = x, D_c_F1 = 1)
# Matrix 12, c = (0, 1): (D_c_F0 = 1, D_c_F1 = 1)
# Matrix 12, c = (1, 0): (D_c_F0 = x, D_c_F1 = x)
# Matrix 12, c = (1, 1): (D_c_F0 = 1, D_c_F1 = x)
# Matrix 13, c = (0, 0): (D_c_F0 = x, D_c_F1 = 0)
# Matrix 13, c = (0, 1): (D_c_F0 = 1, D_c_F1 = 0)
# Matrix 13, c = (1, 0): (D_c_F0 = x, D_c_F1 = x + 1)
# Matrix 13, c = (1, 1): (D_c_F0 = 1, D_c_F1 = x + 1)
# Matrix 14, c = (0, 0): (D_c_F0 = x, D_c_F1 = x + 1)
# Matrix
c = (0, 1): (D_c_F0 = x, D_c_F1 = x + 1)
# Matrix 117, c = (1, 0): (D_c_F0 = 1, D_c_F1 = 0)
# Matrix 117, c = (1, 1): (D_c_F0 = x, D_c_F1 = 0)
# Matrix 118, c = (0, 0): (D_c_F0 = 1, D_c_F1 = x)
# Matrix 118, c = (0, 1): (D_c_F0 = x, D_c_F1 = x)
# Matrix 118, c = (1, 0): (D_c_F0 = 1, D_c_F1 = 1)
# Matrix 118, c = (1, 1): (D_c_F0 = x, D_c_F1 = 1)
# Matrix 119, c = (0, 0): (D_c_F0 = 1, D_c_F1 = 1)
# Matrix 119, c = (0, 1): (D_c_F0 = x, D_c_F1 = 1)
# Matrix 119, c = (1, 0): (D_c_F0 = 1, D_c_F1 = x)
# Matrix 119, c = (1, 1): (D_c_F0 = x, D_c_F1 = x)
# Matrix 120, c = (0, 0): (D_c_F0 = 0, D_c_F1 = 1)
# Matrix 120, c = (0, 1): (D_c_F0 = x + 1, D_c_F1 = 1)
# Matrix 120, c = (1, 0): (D_c_F0 = 0, D_c_F1 = x)
# Matrix 120, c = (1, 1): (D_c_F0 = x + 1, D_c_F1 = x)
# Matrix 121, c = (0, 0): (D_c_F0 = 0, D_c_F1 = x)
# Matrix 121, c = (0, 1): (D_c_F0 = x + 1, D_c_F1 = x)
# Matrix 121, c = (1, 0): (D_c_F0 = 0, D_c_F1 = 1)
# Matrix 121, c = (1, 1): (D_c_F0 = x + 1, D_c_F1 = 1)
# Matrix 122, c = (0, 0): (D_c_F0 = 0, D_c_F1 = x + 1)
# Matrix 122, c = (0, 1): (D_c_F0 = x + 1, D_c_F1 = x + 1)
# Matrix 122, c = (1, 0): (D_c_F0 = 0, D_c_F1 = 0)
# Matrix 122, c = (1, 1): (D_c_F0 = x + 1, D_c_F1 = 0)
# Matrix 123, c = (0, 0): (D_c_F0 = 0, D_c_F1 = 1)
# Matrix 123, c = (0, 1): (D_c_F0 = x + 1, D_c_F1 = 1)
# Matrix 123, c = (1, 0): (D_c_F0 = 0, D_c_F1 = x)
# Matrix 123, c = (1, 1): (D_c_F0 = x + 1, D_c_F1 = x)
# Matrix 124, c = (0, 0): (D_c_F0 = 0, D_c_F1 = 0)
# Matrix 124, c = (0, 1): (D_c_F0 = x + 1, D_c_F1 = 0)
# Matrix 124, c = (1, 0): (D_c_F0 = 0, D_c_F1 = x + 1)
# Matrix 124, c = (1, 1): (D_c_F0 = x + 1, D_c_F1 = x + 1)
# Matrix 125, c = (0, 0): (D_c_F0 = 0, D_c_F1 = x)
# Matrix 125, c = (0, 1): (D_c_F0 = x + 1, D_c_F1 = x)
# Matrix 125, c = (1, 0): (D_c_F0 = 0, D_c_F1 = 1)
# Matrix 125, c = (1, 1): (D_c_F0 = x + 1, D_c_F1 = 1)
# Matrix 126, c = (0, 0): (D_c_F0 = 0, D_c_F1 = x)
# Matrix 126, c = (0, 1): (D_c_F0 = x + 1, D_c_F1 = x)
# Matrix 126, c = (1, 0): (D_c_F0 = 0, D_c_F1 = 1)
# Matrix 126, c = (1, 1): (D_c_F0 = x + 1, D_c_F1 = 1)
# Matrix 127, c = (0, 0): (D_c_F0 = 0, D_c_F1 = x + 1)
# Matrix 127, c = (0, 1): (D_c_F0 = x + 1, D_c_F1 = x + 1)
# Matrix 127, c = (1, 0): (D_c_F0 = 0, D_c_F1 = 0)
# Matrix 127, c = (1, 1): (D_c_F0 = x + 1, D_c_F1 = 0)
# Matrix 128, c = (0, 0): (D_c_F0 = 0, D_c_F1 = 0)
# Matrix 128, c = (0, 1): (D_c_F0 = x + 1, D_c_F1 = 0)
# Matrix 128, c = (1, 0): (D_c_F0 = 0, D_c_F1 = x + 1)
# Matrix 128, c = (1, 1): (D_c_F0 = x + 1, D_c_F1 = x + 1)
# Matrix 129, c = (0, 0): (D_c_F0 = 0, D_c_F1 = x + 1)
# Matrix 129, c = (0, 1): (D_c_F0 = x + 1, D_c_F1 = x + 1)
# Matrix 129, c = (1, 0): (D_c_F0 = 0, D_c_F1 = 0)
# Matrix 129, c = (1, 1): (D_c_F0 = x + 1, D_c_F1 = 0)
# Matrix 130, c = (0, 0): (D_c_F0 = 0, D_c_F1 = 1)
# Matrix 130, c = (0, 1): (D_c_F0 = x + 1, D_c_F1 = 1)
# Matrix 130, c = (1, 0): (D_c_F0 = 0, D_c_F1 = x)
# Matrix 130, c = (1, 1): (D_c_F0 = x + 1, D_c_F1 = x)
# Matrix 131, c = (0, 0): (D_c_F0 = 0, D_c_F1 = 0)
# Matrix 131, c = (0, 1): (D_c_F0 = x + 1, D_c_F1 = 0)
# Matrix 131, c = (1, 0): (D_c_F0 = 0, D_c_F1 = x + 1)
# Matrix 131, c = (1, 1): (D_c_F0 = x + 1, D_c_F1 = x + 1)
# Matrix 132, c = (0, 0): (D_c_F0 = x, D_c_F1 = 1)
# Matrix 132, c = (0, 1): (D_c_F0 = 1, D_c_F1 = 1)
# Matrix 132, c = (1, 0): (D_c_F0 = x, D_c_F1 = x)
# Matrix 132, c = (1, 1): (D_c_F0 = 1, D_c_F1 = x)
# Matrix 133, c = (0, 0): (D_c_F0 = x, D_c_F1 = x)
# Matrix 133, c = (0, 1): (D_c_F0 = 1, D_c_F1 = x)
# Matrix 133, c = (1, 0): (D_c_F0 = x, D_c_F1 = 1)
# Matrix 133, c = (1, 1): (D_c_F0 = 1, D_c_F1 = 1)
# Matrix 134, c = (0, 0): (D_c_F0 = x, D_c_F1 = x + 1)
# Matrix 134, c = (0, 1): (D_c_F0 = 1, D_c_F1 = x + 1)
# Matrix 134, c = (1, 0): (D_c_F0 = x, D_c_F1 = 0)
# Matrix 134, c = (1, 1): (D_c_F0 = 1, D_c_F1 = 0)
# Matrix 135, c = (0, 0): (D_c_F0 = x, D_c_F1 = 0)
# Matrix 135, c = (0, 1): (D_c_F0 = 1, D_c_F1 = 0)
# Matrix 135, c = (1, 0): (D_c_F0 = x, D_c_F1 = x + 1)
# Matrix 135, c = (1, 1): (D_c_F0 = 1, D_c_F1 = x + 1)
# Matrix 136, c = (0, 0): (D_c_F0 = x, D_c_F1 = x + 1)
# Matrix 136, c = (0, 1): (D_c_F0 = 1, D_c_F1 = x + 1)
# Matrix 136, c = (1, 0): (D_c_F0 = x, D_c_F1 = 0)
# Matrix 136, c = (1, 1): (D_c_F0 = 1, D_c_F1 = 0)
# Matrix 137, c = (0, 0): (D_c_F0 = x, D_c_F1 = x)
# Matrix 137, c = (0, 1): (D_c_F0 = 1, D_c_F1 = x)
# Matrix 137, c = (1, 0): (D_c_F0 = x, D_c_F1 = 1)
# Matrix 137, c = (1, 1): (D_c_F0 = 1, D_c_F1 = 1)
# Matrix 138, c = (0, 0): (D_c_F0 = x, D_c_F1 = x + 1)
# Matrix 138, c = (0, 1): (D_c_F0 = 1, D_c_F1 = x + 1)
# Matrix 138, c = (1, 0): (D_c_F0 = x, D_c_F1 = 0)
# Matrix 138, c = (1, 1): (D_c_F0 = 1, D_c_F1 = 0)
# Matrix 139, c = (0, 0): (D_c_F0 = x, D_c_F1 = 0)
# Matrix 139, c = (0, 1): (D_c_F0 = 1, D_c_F1 = 0)
# Matrix 139, c = (1, 0): (D_c_F0 = x, D_c_F1 = x + 1)
# Matrix 139, c = (1, 1): (D_c_F0 = 1, D_c_F1 = x + 1)
# Matrix 140, c = (0, 0): (D_c_F0 = x, D_c_F1 = 1)
# Matrix 140, c = (0, 1): (D_c_F0 = 1, D_c_F1 = 1)
# Matrix 140, c = (1, 0): (D_c_F0 = x, D_c_F1 = x)
# Matrix 140, c = (1, 1): (D_c_F0 = 1, D_c_F1 = x)
# Matrix 141, c = (0, 0): (D_c_F0 = x, D_c_F1 = x)
# Matrix 141, c = (0, 1): (D_c_F0 = 1, D_c_F1 = x)
# Matrix 141, c = (1, 0): (D_c_F0 = x, D_c_F1 = 1)
# Matrix 141, c = (1, 1): (D_c_F0 = 1, D_c_F1 = 1)
# Matrix 142, c = (0, 0): (D_c_F0 = x, D_c_F1 = 1)
# Matrix 142, c = (0, 1): (D_c_F0 = 1, D_c_F1 = 1)
# Matrix 142, c = (1, 0): (D_c_F0 = x, D_c_F1 = x)
# Matrix 142, c = (1, 1): (D_c_F0 = 1, D_c_F1 = x)
# Matrix 143, c = (0, 0): (D_c_F0 = x, D_c_F1 = 0)
# Matrix 143, c = (0, 1): (D_c_F0 = 1, D_c_F1 = 0)
# Matrix 143, c = (1, 0): (D_c_F0 = x, D_c_F1 = x + 1)
# Matrix 143, c = (1, 1): (D_c_F0 = 1, D_c_F1 = x + 1)
# Matrix 144, c = (0, 0): (D_c_F0 = x + 1, D_c_F1 = 1)
# Matrix 144, c = (0, 1): (D_c_F0 = 0, D_c_F1 = 1)
# Matrix 144, c = (1, 0): (D_c_F0 = x + 1, D_c_F1 = x)
# Matrix 144, c = (1, 1): (D_c_F0 = 0, D_c_F1 = x)
# Matrix 145, c = (0, 0): (D_c_F0 = x + 1, D_c_F1 = x)
# Matrix 145, c = (0, 1): (D_c_F0 = 0, D_c_F1 = x)
# Matrix 145, c = (1, 0): (D_c_F0 = x + 1, D_c_F1 = 1)
# Matrix 145, c = (1, 1): (D_c_F0 = 0, D_c_F1 = 1)
# Matrix 146, c = (0, 0): (D_c_F0 = x + 1, D_c_F1 = x + 1)
# Matrix 146, c = (0, 1): (D_c_F0 = 0, D_c_F1 = x + 1)
# Matrix 146, c = (1, 0): (D_c_F0 = x + 1, D_c_F1 = 0)
# Matrix 146, c = (1, 1): (D_c_F0 = 0, D_c_F1 = 0)
# Matrix 147, c = (0, 0): (D_c_F0 = x + 1, D_c_F1 = 1)
# Matrix 147, c = (0, 1): (D_c_F0 = 0, D_c_F1 = 1)
# Matrix 147, c = (1, 0): (D_c_F0 = x + 1, D_c_F1 = x)
# Matrix 147, c = (1, 1): (D_c_F0 = 0, D_c_F1 = x)
# Matrix 148, c = (0, 0): (D_c_F0 = x + 1, D_c_F1 = 0)
# Matrix 148, c = (0, 1): (D_c_F0 = 0, D_c_F1 = 0)
# Matrix 148, c = (1, 0): (D_c_F0 = x + 1, D_c_F1 = x + 1)
# Matrix 148, c = (1, 1): (D_c_F0 = 0, D_c_F1 = x + 1)
# Matrix 149, c = (0, 0): (D_c_F0 = x + 1, D_c_F1 = x)
# Matrix 149, c = (0, 1): (D_c_F0 = 0, D_c_F1 = x)
# Matrix 149, c = (1, 0): (D_c_F0 = x + 1, D_c_F1 = 1)
# Matrix 149, c = (1, 1): (D_c_F0 = 0, D_c_F1 = 1)
# Matrix 150, c = (0, 0): (D_c_F0 = x + 1, D_c_F1 = x)
# Matrix 150, c = (0, 1): (D_c_F0 = 0, D_c_F1 = x)
# Matrix 150, c = (1, 0): (D_c_F0 = x + 1, D_c_F1 = 1)
# Matrix 150, c = (1, 1): (D_c_F0 = 0, D_c_F1 = 1)
# Matrix 151, c = (0, 0): (D_c_F0 = x + 1, D_c_F1 = x + 1)
# Matrix 151, c = (0, 1): (D_c_F0 = 0, D_c_F1 = x + 1)
# Matrix 151, c = (1, 0): (D_c_F0 = x + 1, D_c_F1 = 0)
# Matrix 151, c = (1, 1): (D_c_F0 = 0, D_c_F1 = 0)
# Matrix 152, c = (0, 0): (D_c_F0 = x + 1, D_c_F1 = 0)
# Matrix 152, c = (0, 1): (D_c_F0 = 0, D_c_F1 = 0)
# Matrix 152, c = (1, 0): (D_c_F0 = x + 1, D_c_F1 = x + 1)
# Matrix 152, c = (1, 1): (D_c_F0 = 0, D_c_F1 = x + 1)
# Matrix 153, c = (0, 0): (D_c_F0 = x + 1, D_c_F1 = x + 1)
# Matrix 153, c = (0, 1): (D_c_F0 = 0, D_c_F1 = x + 1)
# Matrix 153, c = (1, 0): (D_c_F0 = x + 1, D_c_F1 = 0)
# Matrix 153, c = (1, 1): (D_c_F0 = 0, D_c_F1 = 0)
# Matrix 154, c = (0, 0): (D_c_F0 = x + 1, D_c_F1 = 1)
# Matrix 154, c = (0, 1): (D_c_F0 = 0, D_c_F1 = 1)
# Matrix 154, c = (1, 0): (D_c_F0 = x + 1, D_c_F1 = x)
# Matrix 154, c = (1, 1): (D_c_F0 = 0, D_c_F1 = x)
# Matrix 155, c = (0, 0): (D_c_F0 = x + 1, D_c_F1 = 0)
# Matrix 155, c = (0, 1): (D_c_F0 = 0, D_c_F1 = 0)
# Matrix 155, c = (1, 0): (D_c_F0 = x + 1, D_c_F1 = x + 1)
# Matrix 155, c = (1, 1): (D_c_F0 = 0, D_c_F1 = x + 1)
# Matrix 156, c = (0, 0): (D_c_F0 = 0, D_c_F1 = 1)
# Matrix 156, c = (0, 1): (D_c_F0 = x + 1, D_c_F1 = 1)
# Matrix 156, c = (1, 0): (D_c_F0 = 0, D_c_F1 = x)
# Matrix 156, c = (1, 1): (D_c_F0 = x + 1, D_c_F1 = x)
# Matrix 157, c = (0, 0): (D_c_F0 = 0, D_c_F1 = x)
# Matrix 157, c = (0, 1): (D_c_F0 = x + 1, D_c_F1 = x)
# Matrix 157, c = (1, 0): (D_c_F0 = 0, D_c_F1 = 1)
# Matrix 157, c = (1, 1): (D_c_F0 = x + 1, D_c_F1 = 1)
# Matrix 158, c = (0, 0): (D_c_F0 = 0, D_c_F1 = x + 1)
# Matrix 158, c = (0, 1): (D_c_F0 = x + 1, D_c_F1 = x + 1)
# Matrix 158, c = (1, 0): (D_c_F0 = 0, D_c_F1 = 0)
# Matrix 158, c = (1, 1): (D_c_F0 = x + 1, D_c_F1 = 0)
# Matrix 159, c = (0, 0): (D_c_F0 = 0, D_c_F1 = 1)
# Matrix 159, c = (0, 1): (D_c_F0 = x + 1, D_c_F1 = 1)
# Matrix 159, c = (1, 0): (D_c_F0 = 0, D_c_F1 = x)
# Matrix 159, c = (1, 1): (D_c_F0 = x + 1, D_c_F1 = x)
# Matrix 160, c = (0, 0): (D_c_F0 = 0, D_c_F1 = 0)
# Matrix 160, c = (0, 1): (D_c_F0 = x + 1, D_c_F1 = 0)
# Matrix 160, c = (1, 0): (D_c_F0 = 0, D_c_F1 = x + 1)
# Matrix 160, c = (1, 1): (D_c_F0 = x + 1, D_c_F1 = x + 1)
# Matrix 161, c = (0, 0): (D_c_F0 = 0, D_c_F1 = x + 1)
# Matrix 161, c = (0, 1): (D_c_F0 = x + 1, D_c_F1 = x + 1)
# Matrix 161, c = (1, 0): (D_c_F0 = 0, D_c_F1 = 0)
# Matrix 161, c = (1, 1): (D_c_F0 = x + 1, D_c_F1 = 0)
# Matrix 162, c = (0, 0): (D_c_F0 = 0, D_c_F1 = x)
# Matrix 162, c = (0, 1): (D_c_F0 = x + 1, D_c_F1 = x)
# Matrix 162, c = (1, 0): (D_c_F0 = 0, D_c_F1 = 1)
# Matrix 162, c = (1, 1): (D_c_F0 = x + 1, D_c_F1 = 1)
# Matrix 163, c = (0, 0): (D_c_F0 = 0, D_c_F1 = 0)
# Matrix 163, c = (0, 1): (D_c_F0 = x + 1, D_c_F1 = 0)
# Matrix 163, c = (1, 0): (D_c_F0 = 0, D_c_F1 = x + 1)
# Matrix 163, c = (1, 1): (D_c_F0 = x + 1, D_c_F1 = x + 1)
# Matrix 164, c = (0, 0): (D_c_F0 = 0, D_c_F1 = 1)
# Matrix 164, c = (0, 1): (D_c_F0 = x + 1, D_c_F1 = 1)
# Matrix 164, c = (1, 0): (D_c_F0 = 0, D_c_F1 = x)
# Matrix 164, c = (1, 1): (D_c_F0 = x + 1, D_c_F1 = x)
# Matrix 165, c = (0, 0): (D_c_F0 = 0, D_c_F1 = x + 1)
# Matrix 165, c = (0, 1): (D_c_F0 = x + 1, D_c_F1 = x + 1)
# Matrix 165, c = (1, 0): (D_c_F0 = 0, D_c_F1 = 0)
# Matrix 165, c = (1, 1): (D_c_F0 = x + 1, D_c_F1 = 0)
# Matrix 166, c = (0, 0): (D_c_F0 = 0, D_c_F1 = x)
# Matrix 166, c = (0, 1): (D_c_F0 = x + 1, D_c_F1 = x)
# Matrix 166, c = (1, 0): (D_c_F0 = 0, D_c_F1 = 1)
# Matrix 166, c = (1, 1): (D_c_F0 = x + 1, D_c_F1 = 1)
# Matrix 167, c = (0, 0): (D_c_F0 = 0, D_c_F1 = 0)
# Matrix 167, c = (0, 1): (D_c_F0 = x + 1, D_c_F1 = 0)
# Matrix 167, c = (1, 0): (D_c_F0 = 0, D_c_F1 = x + 1)
# Matrix 167, c = (1, 1): (D_c_F0 = x + 1, D_c_F1 = x + 1)
# Matrix 168, c = (0, 0): (D_c_F0 = 1, D_c_F1 = 1)
# Matrix 168, c = (0, 1): (D_c_F0 = x, D_c_F1 = 1)
# Matrix 168, c = (1, 0): (D_c_F0 = 1, D_c_F1 = x)
# Matrix 168, c = (1, 1): (D_c_F0 = x, D_c_F1 = x)
# Matrix 169, c = (0, 0): (D_c_F0 = 1, D_c_F1 = x)
# Matrix 169, c = (0, 1): (D_c_F0 = x, D_c_F1 = x)
# Matrix 169, c = (1, 0): (D_c_F0 = 1, D_c_F1 = 1)
# Matrix 169, c = (1, 1): (D_c_F0 = x, D_c_F1 = 1)
# Matrix 170, c = (0, 0): (D_c_F0 = 1, D_c_F1 = x + 1)
# Matrix 170, c = (0, 1): (D_c_F0 = x, D_c_F1 = x + 1)
# Matrix 170, c = (1, 0): (D_c_F0 = 1, D_c_F1 = 0)
# Matrix 170, c = (1, 1): (D_c_F0 = x, D_c_F1 = 0)
# Matrix 171, c = (0, 0): (D_c_F0 = 1, D_c_F1 = 1)
# Matrix 171, c = (0, 1): (D_c_F0 = x, D_c_F1 = 1)
# Matrix 171, c = (1, 0): (D_c_F0 = 1, D_c_F1 = x)
# Matrix 171, c = (1, 1): (D_c_F0 = x, D_c_F1 = x)
# Matrix 172, c = (0, 0): (D_c_F0 = 1, D_c_F1 = x + 1)
# Matrix 172, c = (0, 1): (D_c_F0 = x, D_c_F1 = x + 1)
# Matrix 172, c = (1, 0): (D_c_F0 = 1, D_c_F1 = 0)
# Matrix 172, c = (1, 1): (D_c_F0 = x, D_c_F1 = 0)
# Matrix 173, c = (0, 0): (D_c_F0 = 1, D_c_F1 = x)
# Matrix 173, c = (0, 1): (D_c_F0 = x, D_c_F1 = x)
# Matrix 173, c = (1, 0): (D_c_F0 = 1, D_c_F1 = 1)
# Matrix 173, c = (1, 1): (D_c_F0 = x, D_c_F1 = 1)
# Matrix 174, c = (0, 0): (D_c_F0 = 1, D_c_F1 = x)
# Matrix 174, c = (0, 1): (D_c_F0 = x, D_c_F1 = x)
# Matrix 174, c = (1, 0): (D_c_F0 = 1, D_c_F1 = 1)
# Matrix 174, c = (1, 1): (D_c_F0 = x, D_c_F1 = 1)
# Matrix 175, c = (0, 0): (D_c_F0 = 1, D_c_F1 = x + 1)
# Matrix 175, c = (0, 1): (D_c_F0 = x, D_c_F1 = x + 1)
# Matrix 175, c = (1, 0): (D_c_F0 = 1, D_c_F1 = 0)
# Matrix 175, c = (1, 1): (D_c_F0 = x, D_c_F1 = 0)
# Matrix 176, c = (0, 0): (D_c_F0 = 1, D_c_F1 = 1)
# Matrix 176, c = (0, 1): (D_c_F0 = x, D_c_F1 = 1)
# Matrix 176, c = (1, 0): (D_c_F0 = 1, D_c_F1 = x)
# Matrix 176, c = (1, 1): (D_c_F0 = x, D_c_F1 = x)
# Matrix 177, c = (0, 0): (D_c_F0 = 1, D_c_F1 = x + 1)
# Matrix 177, c = (0, 1): (D_c_F0 = x, D_c_F1 = x + 1)
# Matrix 177, c = (1, 0): (D_c_F0 = 1, D_c_F1 = 0)
# Matrix 177, c = (1, 1): (D_c_F0 = x, D_c_F1 = 0)
# Matrix 178, c = (0, 0): (D_c_F0 = 1, D_c_F1 = x)
# Matrix 178, c = (0, 1): (D_c_F0 = x, D_c_F1 = x)
# Matrix 178, c = (1, 0): (D_c_F0 = 1, D_c_F1 = 1)
# Matrix 178, c = (1, 1): (D_c_F0 = x, D_c_F1 = 1)
# Matrix 179, c = (0, 0): (D_c_F0 = 1, D_c_F1 = 1)
# Matrix 179, c = (0, 1): (D_c_F0 = x, D_c_F1 = 1)
# Matrix 179, c = (1, 0): (D_c_F0 = 1, D_c_F1 = x)
# Matrix 179, c = (1, 1): (D_c_F0 = x, D_c_F1 = x)
