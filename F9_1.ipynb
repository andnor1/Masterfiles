# %%
import galois
from collections import Counter

# Define GF(3)
GF3 = galois.GF(3)

def F_0(x0, x1):
    """Computes F_0(x0, x1) = x0 * x1 (Boolean AND in GF(3))"""
    return x0 * x1  # Multiplication in GF(3)

def F_1(x0, x1):
    """Computes F_1(x0, x1) = x0 + x1 + GF3(2)"""
    return x0 + x1 + GF3(2)  # Addition in GF(3)

def product(u, v):
    """Defines the product (u0,u1) * (v0,v1) over GF(3) with given polynomial."""
    u0, u1 = u
    v0, v1 = v
    return (u0 * v0 + u1 * v1, u0 * v1 + u1 * v0 + 2 * u1 * v1)

def compute_c_derivative(xa, x, c0, c1):
    """
    Computes the c-differential: D_c F(x, a) = F(x + a) - c * F(x).
    """
    x_a0, x_a1 = GF3(xa[0]), GF3(xa[1])
    x0, x1 = GF3(x[0]), GF3(x[1])
    c0, c1 = GF3(c0), GF3(c1)

    # Compute F(x + a)
    Fx_a0 = F_0(x_a0, x_a1)
    Fx_a1 = F_1(x_a0, x_a1)

    # Compute c * F(x) using the defined product
    c_Fx0, c_Fx1 = product((c0, c1), (F_0(x0, x1), F_1(x0, x1)))

    # Compute D_c F(x, a) = F(x + a) - c * F(x)
    D_c_F0 = Fx_a0 - c_Fx0  # Subtraction in GF(3)
    D_c_F1 = Fx_a1 - c_Fx1

    return (int(D_c_F0), int(D_c_F1))

# Generate all possible values for a, x, and c
a_values = [(GF3(a0), GF3(a1)) for a0 in range(3) for a1 in range(3)]
x_values = [(GF3(x0), GF3(x1)) for x0 in range(3) for x1 in range(3)]
c_values = [(GF3(c0), GF3(c1)) for c0 in range(3) for c1 in range(3)]

# Compute D_c F for all a, x, and (c0, c1) combinations
results = []
total_counter = Counter()
a_counters = {tuple(map(int, a)): Counter() for a in a_values}

for a in a_values:
    a_tuple = tuple(map(int, a))
    for x in x_values:
        x_tuple = tuple(map(int, x))
        x_a = (int(x[0] + a[0]), int(x[1] + a[1]))  # Compute x + a using GF(3) addition
        for c0, c1 in c_values:
            c_tuple = (int(c0), int(c1))
            D_c_F = compute_c_derivative(x_a, x, c0, c1)
            results.append((c_tuple, a_tuple, x_tuple, D_c_F))
            a_counters[a_tuple][tuple(D_c_F)] += 1  # Counter for each a
            total_counter[tuple(D_c_F)] += 1  # Total counter

# Sort results by c -> a -> x
results.sort()

# Display results
print("\n## Final Results (binary):")
previous_a = None
for c_tuple, a_tuple, x_tuple, (expr1, expr2) in results:
    if previous_a is not None and previous_a != a_tuple:
        print()  # Add space between different a values
    print(f"c = {c_tuple}, a = {a_tuple}, x = {x_tuple}: (D_c_F0 = {expr1}, D_c_F1 = {expr2})")
    previous_a = a_tuple

# Display count of different results per a
print("\n## Result Counts Per a:")
for a, counter in sorted(a_counters.items()):
    print(f"For a = {a}:")
    for key, count in sorted(counter.items()):
        print(f"  Result {key}: {count} occurrences")
    print()

# Display total count of different results
print("\n## Total Result Counts:")
for key, count in sorted(total_counter.items()):
    print(f"Result {key}: {count} occurrences")
# Out:
# ## Final Results (binary):
# c = (0, 0), a = (0, 0), x =
 1): (D_c_F0 = 0, D_c_F1 = 1)
# c = (2, 2), a = (0, 1), x = (0, 2): (D_c_F0 = 1, D_c_F1 = 2)
# c = (2, 2), a = (0, 1), x = (1, 0): (D_c_F0 = 1, D_c_F1 = 1)
# c = (2, 2), a = (0, 1), x = (1, 1): (D_c_F0 = 1, D_c_F1 = 0)
# c = (2, 2), a = (0, 1), x = (1, 2): (D_c_F0 = 1, D_c_F1 = 2)
# c = (2, 2), a = (0, 1), x = (2, 0): (D_c_F0 = 0, D_c_F1 = 2)
# c = (2, 2), a = (0, 1), x = (2, 1): (D_c_F0 = 2, D_c_F1 = 2)
# c = (2, 2), a = (0, 1), x = (2, 2): (D_c_F0 = 1, D_c_F1 = 2)
#
# c = (2, 2), a = (0, 2), x = (0, 0): (D_c_F0 = 2, D_c_F1 = 1)
# c = (2, 2), a = (0, 2), x = (0, 1): (D_c_F0 = 0, D_c_F1 = 2)
# c = (2, 2), a = (0, 2), x = (0, 2): (D_c_F0 = 1, D_c_F1 = 0)
# c = (2, 2), a = (0, 2), x = (1, 0): (D_c_F0 = 2, D_c_F1 = 2)
# c = (2, 2), a = (0, 2), x = (1, 1): (D_c_F0 = 2, D_c_F1 = 1)
# c = (2, 2), a = (0, 2), x = (1, 2): (D_c_F0 = 2, D_c_F1 = 0)
# c = (2, 2), a = (0, 2), x = (2, 0): (D_c_F0 = 2, D_c_F1 = 0)
# c = (2, 2), a = (0, 2), x = (2, 1): (D_c_F0 = 1, D_c_F1 = 0)
# c = (2, 2), a = (0, 2), x = (2, 2): (D_c_F0 = 0, D_c_F1 = 0)
#
# c = (2, 2), a = (1, 0), x = (0, 0): (D_c_F0 = 2, D_c_F1 = 0)
# c = (2, 2), a = (1, 0), x = (0, 1): (D_c_F0 = 1, D_c_F1 = 1)
# c = (2, 2), a = (1, 0), x = (0, 2): (D_c_F0 = 0, D_c_F1 = 2)
# c = (2, 2), a = (1, 0), x = (1, 0): (D_c_F0 = 0, D_c_F1 = 1)
# c = (2, 2), a = (1, 0), x = (1, 1): (D_c_F0 = 1, D_c_F1 = 0)
# c = (2, 2), a = (1, 0), x = (1, 2): (D_c_F0 = 2, D_c_F1 = 2)
# c = (2, 2), a = (1, 0), x = (2, 0): (D_c_F0 = 1, D_c_F1 = 2)
# c = (2, 2), a = (1, 0), x = (2, 1): (D_c_F0 = 1, D_c_F1 = 2)
# c = (2, 2), a = (1, 0), x = (2, 2): (D_c_F0 = 1, D_c_F1 = 2)
#
# c = (2, 2), a = (1, 1), x = (0, 0): (D_c_F0 = 0, D_c_F1 = 1)
# c = (2, 2), a = (1, 1), x = (0, 1): (D_c_F0 = 2, D_c_F1 = 2)
# c = (2, 2), a = (1, 1), x = (0, 2): (D_c_F0 = 1, D_c_F1 = 0)
# c = (2, 2), a = (1, 1), x = (1, 0): (D_c_F0 = 2, D_c_F1 = 2)
# c = (2, 2), a = (1, 1), x = (1, 1): (D_c_F0 = 0, D_c_F1 = 1)
# c = (2, 2), a = (1, 1), x = (1, 2): (D_c_F0 = 1, D_c_F1 = 0)
# c = (2, 2), a = (1, 1), x = (2, 0): (D_c_F0 = 1, D_c_F1 = 0)
# c = (2, 2), a = (1, 1), x = (2, 1): (D_c_F0 = 1, D_c_F1 = 0)
# c = (2, 2), a = (1, 1), x = (2, 2): (D_c_F0 = 1, D_c_F1 = 0)
#
# c = (2, 2), a = (1, 2), x = (0, 0): (D_c_F0 = 1, D_c_F1 = 2)
# c = (2, 2), a = (1, 2), x = (0, 1): (D_c_F0 = 0, D_c_F1 = 0)
# c = (2, 2), a = (1, 2), x = (0, 2): (D_c_F0 = 2, D_c_F1 = 1)
# c = (2, 2), a = (1, 2), x = (1, 0): (D_c_F0 = 1, D_c_F1 = 0)
# c = (2, 2), a = (1, 2), x = (1, 1): (D_c_F0 = 2, D_c_F1 = 2)
# c = (2, 2), a = (1, 2), x = (1, 2): (D_c_F0 = 0, D_c_F1 = 1)
# c = (2, 2), a = (1, 2), x = (2, 0): (D_c_F0 = 1, D_c_F1 = 1)
# c = (2, 2), a = (1, 2), x = (2, 1): (D_c_F0 = 1, D_c_F1 = 1)
# c = (2, 2), a = (1, 2), x = (2, 2): (D_c_F0 = 1, D_c_F1 = 1)
#
# c = (2, 2), a = (2, 0), x = (0, 0): (D_c_F0 = 2, D_c_F1 = 1)
# c = (2, 2), a = (2, 0), x = (0, 1): (D_c_F0 = 2, D_c_F1 = 2)
# c = (2, 2), a = (2, 0), x = (0, 2): (D_c_F0 = 2, D_c_F1 = 0)
# c = (2, 2), a = (2, 0), x = (1, 0): (D_c_F0 = 0, D_c_F1 = 2)
# c = (2, 2), a = (2, 0), x = (1, 1): (D_c_F0 = 2, D_c_F1 = 1)
# c = (2, 2), a = (2, 0), x = (1, 2): (D_c_F0 = 1, D_c_F1 = 0)
# c = (2, 2), a = (2, 0), x = (2, 0): (D_c_F0 = 1, D_c_F1 = 0)
# c = (2, 2), a = (2, 0), x = (2, 1): (D_c_F0 = 2, D_c_F1 = 0)
# c = (2, 2), a = (2, 0), x = (2, 2): (D_c_F0 = 0, D_c_F1 = 0)
#
# c = (2, 2), a = (2, 1), x = (0, 0): (D_c_F0 = 1, D_c_F1 = 2)
# c = (2, 2), a = (2, 1), x = (0, 1): (D_c_F0 = 1, D_c_F1 = 0)
# c = (2, 2), a = (2, 1), x = (0, 2): (D_c_F0 = 1, D_c_F1 = 1)
# c = (2, 2), a = (2, 1), x = (1, 0): (D_c_F0 = 0, D_c_F1 = 0)
# c = (2, 2), a = (2, 1), x = (1, 1): (D_c_F0 = 2, D_c_F1 = 2)
# c = (2, 2), a = (2, 1), x = (1, 2): (D_c_F0 = 1, D_c_F1 = 1)
# c = (2, 2), a = (2, 1), x = (2, 0): (D_c_F0 = 2, D_c_F1 = 1)
# c = (2, 2), a = (2, 1), x = (2, 1): (D_c_F0 = 0, D_c_F1 = 1)
# c = (2, 2), a = (2, 1), x = (2, 2): (D_c_F0 = 1, D_c_F1 = 1)
#
# c = (2, 2), a = (2, 2), x = (0, 0): (D_c_F0 = 0, D_c_F1 = 0)
# c = (2, 2), a = (2, 2), x = (0, 1): (D_c_F0 = 0, D_c_F1 = 1)
# c = (2, 2), a = (2, 2), x = (0, 2): (D_c_F0 = 0, D_c_F1 = 2)
# c = (2, 2), a = (2, 2), x = (1, 0): (D_c_F0 = 0, D_c_F1 = 1)
# c = (2, 2), a = (2, 2), x = (1, 1): (D_c_F0 = 2, D_c_F1 = 0)
# c = (2, 2), a = (2, 2), x = (1, 2): (D_c_F0 = 1, D_c_F1 = 2)
# c = (2, 2), a = (2, 2), x = (2, 0): (D_c_F0 = 0, D_c_F1 = 2)
# c = (2, 2), a = (2, 2), x = (2, 1): (D_c_F0 = 1, D_c_F1 = 2)
# c = (2, 2), a = (2, 2), x = (2, 2): (D_c_F0 = 2, D_c_F1 = 2)
#
# ## Result Counts Per a:
# For a = (0, 0):
#   Result (0, 0): 25 occurrences
#   Result (0, 1): 7 occurrences
#   Result (0, 2): 7 occurrences
#   Result (1, 0): 7 occurrences
#   Result (1, 1): 7 occurrences
#   Result (1, 2): 7 occurrences
#   Result (2, 0): 7 occurrences
#   Result (2, 1): 7 occurrences
#   Result (2, 2): 7 occurrences
#
# For a = (0, 1):
#   Result (0, 0): 7 occurrences
#   Result (0, 1): 16 occurrences
#   Result (0, 2): 7 occurrences
#   Result (1, 0): 7 occurrences
#   Result (1, 1): 16 occurrences
#   Result (1, 2): 7 occurrences
#   Result (2, 0): 7 occurrences
#   Result (2, 1): 7 occurrences
#   Result (2, 2): 7 occurrences
#
# For a = (0, 2):
#   Result (0, 0): 7 occurrences
#   Result (0, 1): 7 occurrences
#   Result (0, 2): 16 occurrences
#   Result (1, 0): 7 occurrences
#   Result (1, 1): 7 occurrences
#   Result (1, 2): 7 occurrences
#   Result (2, 0): 7 occurrences
#   Result (2, 1): 7 occurrences
#   Result (2, 2): 16 occurrences
#
# For a = (1, 0):
#   Result (0, 0): 7 occurrences
#   Result (0, 1): 16 occurrences
#   Result (0, 2): 7 occurrences
#   Result (1, 0): 7 occurrences
#   Result (1, 1): 16 occurrences
#   Result (1, 2): 7 occurrences
#   Result (2, 0): 7 occurrences
#   Result (2, 1): 7 occurrences
#   Result (2, 2): 7 occurrences
#
# For a = (1, 1):
#   Result (0, 0): 7 occurrences
#   Result (0, 1): 7 occurrences
#   Result (0, 2): 7 occurrences
#   Result (1, 0): 7 occurrences
#   Result (1, 1): 7 occurrences
#   Result (1, 2): 7 occurrences
#   Result (2, 0): 7 occurrences
#   Result (2, 1): 7 occurrences
#   Result (2, 2): 25 occurrences
#
# For a = (1, 2):
#   Result (0, 0): 16 occurrences
#   Result (0, 1): 7 occurrences
#   Result (0, 2): 7 occurrences
#   Result (1, 0): 16 occurrences
#   Result (1, 1): 7 occurrences
#   Result (1, 2): 7 occurrences
#   Result (2, 0): 7 occurrences
#   Result (2, 1): 7 occurrences
#   Result (2, 2): 7 occurrences
#
# For a = (2, 0):
#   Result (0, 0): 7 occurrences
#   Result (0, 1): 7 occurrences
#   Result (0, 2): 16 occurrences
#   Result (1, 0): 7 occurrences
#   Result (1, 1): 7 occurrences
#   Result (1, 2): 7 occurrences
#   Result (2, 0): 7 occurrences
#   Result (2, 1): 7 occurrences
#   Result (2, 2): 16 occurrences
#
# For a = (2, 1):
#   Result (0, 0): 16 occurrences
#   Result (0, 1): 7 occurrences
#   Result (0, 2): 7 occurrences
#   Result (1, 0): 16 occurrences
#   Result (1, 1): 7 occurrences
#   Result (1, 2): 7 occurrences
#   Result (2, 0): 7 occurrences
#   Result (2, 1): 7 occurrences
#   Result (2, 2): 7 occurrences
#
# For a = (2, 2):
#   Result (0, 0): 7 occurrences
#   Result (0, 1): 25 occurrences
#   Result (0, 2): 7 occurrences
#   Result (1, 0): 7 occurrences
#   Result (1, 1): 7 occurrences
#   Result (1, 2): 7 occurrences
#   Result (2, 0): 7 occurrences
#   Result (2, 1): 7 occurrences
#   Result (2, 2): 7 occurrences
#
#
# ## Total Result Counts:
# Result (0, 0): 99 occurrences
# Result (0, 1): 99 occurrences
# Result (0, 2): 81 occurrences
# Result (1, 0): 81 occurrences
# Result (1, 1): 81 occurrences
# Result (1, 2): 63 occurrences
# Result (2, 0): 63 occurrences
# Result (2, 1): 63 occurrences
# Result (2, 2): 99 occurrences
